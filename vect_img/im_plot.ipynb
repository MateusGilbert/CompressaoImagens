# %%
import pandas as pd
import matplotlib.pyplot as pl

pl.rcParams['figure.figsize'] = [10,10]
pl.rcParams.update({'font.size': 25})

# %%
filemane = 'out.csv'
im = pd.read_csv('out.csv',header=None)
pl.imshow(im.to_numpy(),cmap='pink')
pl.grid(False)
pl.axis(False)
pl.show()
